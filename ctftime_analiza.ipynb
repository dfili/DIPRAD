# %% [markdown]
# Scrapeing ctftimea dy vidim što mogu izvući

# %%
import pandas as pd
import requests

import numpy as np
# Funkcija za zvati api sa kompletnim error handlingom
import time

def call_api(url):
    for attempt in range(3): 
        try:
            response = requests.get(url, timeout=5)
            if response.status_code == 200:
                return response.json()
            elif response.status_code == 429:  # Rate Limit
                time.sleep(2 ** attempt)
            else:
                time.sleep(1)
        except Exception as e:
            print(f"API call failed: {e}")
            time.sleep(2 ** attempt)  # Exponential backoff
    return None

# %%
# Prikupi info o kategorijama 
url = "https://ctftime.org/api/v1/top/?limit=10"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'2025': [{'team_name': 'kalmarunionen', 'points': 1427.4508506867246, 'team_id': 114856}, {'team_name': 'r3kapig', 'points': 1365.783591555416, 'team_id': 58979}, {'team_name': 'The Flat Network Society', 'points': 1059.400270736656, 'team_id': 87434}, {'team_name': 'Never Stop Exploiting', 'points': 1014.6743285035609, 'team_id': 13575}, {'team_name': 'Nu1L', 'points': 975.7257937616123, 'team_id': 19208}, {'team_name': 'justCatTheFish', 'points': 940.9050172787008, 'team_id': 33893}, {'team_name': 'Project Sekai', 'points': 931.2628233632681, 'team_id': 169557}, {'team_name': '.;,;.', 'points': 924.7634438258598, 'team_id': 222911}, {'team_name': 'thehackerscrew', 'points': 920.5869717618908, 'team_id': 85618}, {'team_name': 'Infobahn', 'points': 886.6042801926711, 'team_id': 364723}]}

# %%
# Info about team
url = "https://ctftime.org/api/v1/teams/114856/"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'academic': False, 'primary_alias': 'kalmarunionen', 'name': 'kalmarunionen', 'rating': {'2016': {'country_place': 5}, '2017': {'country_place': 5}, '2018': {'country_place': 5}, '2019': {'country_place': 6}, '2020': {'rating_place': 66, 'organizer_points': 0, 'rating_points': 281.649461244, 'country_place': 1}, '2021': {'rating_place': 15, 'organizer_points': 0, 'rating_points': 616.861638722, 'country_place': 1}, '2022': {'rating_place': 10, 'organizer_points': 0, 'rating_points': 737.24987219, 'country_place': 1}, '2023': {'rating_place': 3, 'organizer_points': 48.42, 'rating_points': 1271.61352869, 'country_place': 1}, '2024': {'rating_place': 1, 'organizer_points': 48.42, 'rating_points': 1721.03849557, 'country_place': 1}, '2025': {'rating_place': 1, 'organizer_points': 67.78, 'rating_points': 1427.45085069, 'country_place': 1}, '2011': {}, '2012': {'country_place': 2}, '2013': {'country_place': 2}, '2014': {'country_place': 6}, '2015': {'country_place': 2}}, 'logo': 'https://
# ...

# %%
# Info about team
url = "https://ctftime.org/api/v1/users/"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/anaconda3/lib/python3.11/site-packages/simplejson/__init__.py:514, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     510 if (cls is None and encoding is None and object_hook is None and
#     511         parse_int is None and parse_float is None and
#     512         parse_constant is None and object_pairs_hook is None
# ...
